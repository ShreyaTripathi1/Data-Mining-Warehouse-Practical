# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("iris.csv")
df
# Out:
#      5.1  3.5  1.4  0.2  0
# 0    4.9  3.0  1.4  0.2  0
# 1    4.7  3.2  1.3  0.2  0
# 2    4.6  3.1  1.5  0.2  0
# 3    5.0  3.6  1.4  0.2  0
# 4    5.4  3.9  1.7  0.4  0
# ..   ...  ...  ...  ... ..
# 144  6.7  3.0  5.2  2.3  1
# 145  6.3  2.5  5.0  1.9  1
# 146  6.5  3.0  5.2  2.0  1
# 147  6.2  3.4  5.4  2.3  1
# 148  5.9  3.0  5.1  1.8  1
#
# [149 rows x 5 columns]

# %%
plt.figure(figsize=(8,5))
plt.hist(df, bins=5,edgecolor="black",alpha=.6)
# Out:
# (array([[  0.,   0.,   1.,  93.,  55.],
#         [  0.,  19., 129.,   1.,   0.],
#         [  0.,  49.,  25.,  69.,   6.],
#         [ 49., 100.,   0.,   0.,   0.],
#         [ 99.,  50.,   0.,   0.,   0.]]),
#  array([-1.  ,  0.78,  2.56,  4.34,  6.12,  7.9 ]),
#  <a list of 5 BarContainer objects>)

# %%
import seaborn as sns

# %%
plt.figure(figsize=(8,5))

# %%
sns.kdeplot(df, fill=.9)
# Out:
# <Axes: ylabel='Density'>

# %%
import scipy.stats as stats

t_stat, p_value = stats.ttest_ind(df["Product 1"], df["Product 2"])
print("T-statistic:", t_stat)
print("P-value:", p_value)
